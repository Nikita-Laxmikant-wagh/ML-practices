# %% [markdown]
# #k-fold cross validation apply on KNN Algorithm to find best hyper parameter

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,recall_score,precision_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("/content/heart.csv")

# %%
x=df.drop(columns="target",axis=1)
y=df["target"]

# %%
# Splitting the dataset into Training and Testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
# Scale the values
scalar = StandardScaler()

# %%
# Train the model using KNN algorithm
x_train_scaled = scalar.fit_transform(x_train)
x_test_scaled = scalar.fit_transform(x_test)

KNN_model = KNeighborsClassifier(n_neighbors=3)
KNN_model.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = KNN_model.predict(x_test_scaled)

# %%
# Evaluate the model Performance
print(accuracy_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(precision_score(y_test,y_pred))
# Out:
# 0.9365853658536586
# 0.9
# 0.967741935483871

# %%
# Apply K-Fold Cross Validation
classifires = KNeighborsClassifier()
grid_params = {
    "n_neighbors":[3,5,7,9]
}
classifire_cv = GridSearchCV(
  classifires,
  grid_params,
  cv=5
  )
classifire_cv.fit(x_train_scaled,y_train)
y_pred = classifire_cv.predict(x_test_scaled)
# Out:
# 0.9365853658536586
# 0.9
# 0.967741935483871

# %%
# Evaluate model Again
print(accuracy_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(precision_score(y_test,y_pred))
# Out:
# 0.9365853658536586
# 0.9
# 0.967741935483871

# %%
res = pd.DataFrame(classifire_cv.cv_results_)
res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002628      0.000349         0.005665        0.000634
# 1       0.002114      0.000039         0.005688        0.000288
# 2       0.002243      0.000091         0.006410        0.000533
# 3       0.002486      0.000319         0.006231        0.000311
#
#    param_n_neighbors              params  split0_test_score  \
# 0                  3  {'n_neighbors': 3}           0.896341
# 1                  5  {'n_neighbors': 5}           0.823171
# 2                  7  {'n_neighbors': 7}           0.865854
# 3                  9  {'n_neighbors': 9}           0.847561
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.865854           0.871951           0.914634           0.939024
# 1           0.817073           0.810976           0.853659           0.878049
# 2           0.817073           0.798780           0.871951           0.871951
# ...
