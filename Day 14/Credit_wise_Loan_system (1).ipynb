# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("/content/loan_approval_data.csv")

# %%
data.head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           1.0           17795.0              1387.0          Salaried  51.0
# 1           2.0            2860.0              2679.0          Salaried  46.0
# 2           3.0            7390.0              2106.0          Salaried  25.0
# 3           4.0           13964.0              8173.0          Salaried  40.0
# 4           5.0           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# ...

# %%
data.shape
# Out:
# (1000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_ID        950 non-null    float64
#  1   Applicant_Income    950 non-null    float64
#  2   Coapplicant_Income  950 non-null    float64
#  3   Employment_Status   950 non-null    object
#  4   Age                 950 non-null    float64
#  5   Marital_Status      950 non-null    object
#  6   Dependents          950 non-null    float64
#  7   Credit_Score        950 non-null    float64
#  8   Existing_Loans      950 non-null    float64
#  9   DTI_Ratio           950 non-null    float64
#  10  Savings             950 non-null    float64
#  11  Collateral_Value    950 non-null    float64
#  12  Loan_Amount         950 non-null    float64
#  13  Loan_Term           950 non-null    float64
#  14  Loan_Purpose        950 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# Applicant_ID          50
# Applicant_Income      50
# Coapplicant_Income    50
# Employment_Status     50
# Age                   50
# Marital_Status        50
# Dependents            50
# Credit_Score          50
# Existing_Loans        50
# DTI_Ratio             50
# Savings               50
# Collateral_Value      50
# Loan_Amount           50
# Loan_Term             50
# Loan_Purpose          50
# Property_Area         50
# Education_Level       50
# Gender                50
# Employer_Category     50
# Loan_Approved         50
# dtype: int64

# %%
data.describe()
# Out:
#        Applicant_ID  Applicant_Income  Coapplicant_Income         Age  \
# count    950.000000        950.000000          950.000000  950.000000
# mean     501.220000      10852.571579         5082.455789   39.971579
# std      289.608451       5061.632859         2943.161570   11.139797
# min        1.000000       2009.000000            1.000000   21.000000
# 25%      250.250000       6730.750000         2472.750000   30.250000
# 50%      499.500000      10548.000000         5205.500000   40.000000
# 75%      752.750000      15190.000000         7620.750000   49.000000
# max     1000.000000      19988.000000         9996.000000   59.000000
#
#        Dependents  Credit_Score  Existing_Loans   DTI_Ratio       Savings  \
# count  950.000000    950.000000      950.000000  950.000000    950.000000
# mean     1.474737    676.033684        1.950526    0.347263   9940.452632
# std      1.105067     71.346015        1.406246    0.144341   5860.736885
# ...

# %% [markdown]
# # Handle Missing Values

# %%
categorical_cols = data.select_dtypes(include=['object']).columns
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns

# %%
categorical_cols
# Out:
# Index(['Employment_Status', 'Marital_Status', 'Loan_Purpose', 'Property_Area',
#        'Education_Level', 'Gender', 'Employer_Category', 'Loan_Approved'],
#       dtype='object')

# %%
numerical_cols
# Out:
# Index(['Applicant_ID', 'Applicant_Income', 'Coapplicant_Income', 'Age',
#        'Dependents', 'Credit_Score', 'Existing_Loans', 'DTI_Ratio', 'Savings',
#        'Collateral_Value', 'Loan_Amount', 'Loan_Term'],
#       dtype='object')

# %%
from pandas.core.arrays.categorical import Categorical
from sklearn.impute import SimpleImputer

Categorical_imputer = SimpleImputer(strategy='most_frequent')
data[categorical_cols] =Categorical_imputer.fit_transform(data[categorical_cols])

numerical_imputer = SimpleImputer(strategy='mean')
data[numerical_cols] = numerical_imputer.fit_transform(data[numerical_cols])

# %%
data.isnull().sum()
# Out:
# Applicant_ID          0
# Applicant_Income      0
# Coapplicant_Income    0
# Employment_Status     0
# Age                   0
# Marital_Status        0
# Dependents            0
# Credit_Score          0
# Existing_Loans        0
# DTI_Ratio             0
# Savings               0
# Collateral_Value      0
# Loan_Amount           0
# Loan_Term             0
# Loan_Purpose          0
# Property_Area         0
# Education_Level       0
# Gender                0
# Employer_Category     0
# Loan_Approved         0
# dtype: int64

# %%
data.head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           1.0           17795.0              1387.0          Salaried  51.0
# 1           2.0            2860.0              2679.0          Salaried  46.0
# 2           3.0            7390.0              2106.0          Salaried  25.0
# 3           4.0           13964.0              8173.0          Salaried  40.0
# 4           5.0           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA) :-

# %%
classess_count = data['Loan_Approved'].value_counts()
plt.pie(classess_count, labels=classess_count.index, autopct='%1.0f%%')
plt.title('Classes Distribution')
plt.show()

# %%
# Analysis Categorical columns

# %%
gender_count = data['Gender'].value_counts()
sns.barplot(x=gender_count.index, y=gender_count.values, palette='pastel')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()
# Out:
# /tmp/ipykernel_7797/1979620708.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_count.index, y=gender_count.values, palette='pastel')

# %%
education_count = data['Education_Level'].value_counts()
sns.barplot(x=education_count.index, y=education_count.values)
plt.title('Education Distribution')
plt.show()

# %%
emp_status_count = data['Employment_Status'].value_counts()
sns.barplot(x=emp_status_count.index, y=emp_status_count.values)
plt.title('Employee Status Distribution')
plt.show()

# %%
emp_category_count = data['Employer_Category'].value_counts()
sns.barplot(x=emp_category_count.index, y=emp_category_count.values)
plt.title('Employee Category Distribution')
plt.show()

# %%
loan_purpose_count = data['Loan_Purpose'].value_counts()
sns.barplot(x=loan_purpose_count.index, y=loan_purpose_count.values)
plt.title('Loan Purpose Distribution')
plt.show()

# %% [markdown]
# # Find Important Features

# %%
sns.histplot(
    data=data,
    x='Credit_Score',
    hue='Loan_Approved',
    bins=20,
    multiple ="dodge"
)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
sns.histplot(
    data=data,
    x='Applicant_Income',
    hue='Loan_Approved',
    bins=20,
    multiple ="dodge"
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
sns.histplot(
    data=data,
    x='Employment_Status',
    hue='Loan_Approved',
    bins=20,
    multiple ="dodge"
)
# Out:
# <Axes: xlabel='Employment_Status', ylabel='Count'>

# %% [markdown]
# # Remove Unneccessary Columns

# %%
data = data.drop(columns=["Applicant_ID"], errors='ignore')
data.head()
# Out:
#    Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           17795.0              1387.0          Salaried  51.0
# 1            2860.0              2679.0          Salaried  46.0
# 2            7390.0              2106.0          Salaried  25.0
# 3           13964.0              8173.0          Salaried  40.0
# 4           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0  19403.0           45638.0      16619.0       84.0     Personal
# ...

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

label_encoder = LabelEncoder()
data['Education_Level'] = label_encoder.fit_transform(data['Education_Level'])
data['Loan_Approved'] = label_encoder.fit_transform(data['Loan_Approved'])
data.head()
# Out:
#    Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           17795.0              1387.0          Salaried  51.0
# 1            2860.0              2679.0          Salaried  46.0
# 2            7390.0              2106.0          Salaried  25.0
# 3           13964.0              8173.0          Salaried  40.0
# 4           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0  19403.0           45638.0      16619.0       84.0     Personal
# ...

# %%
cols=["Gender", "Marital_Status", "Employment_Status", "Employer_Category", "Loan_Purpose","Property_Area"]
one_hot_encoder=OneHotEncoder(drop="first", sparse_output=False, handle_unknown="ignore")

# Filter cols to only include columns still present in data
current_categorical_cols = [col for col in cols if col in data.columns]

if current_categorical_cols: # Only proceed if there are columns to encode
    # Fit and transform the selected categorical columns
    encoded_features = one_hot_encoder.fit_transform(data[current_categorical_cols])

    # Get the new column names after one-hot encoding
    encoded_feature_names = one_hot_encoder.get_feature_names_out(current_categorical_cols)

    # Create a DataFrame from the encoded features
    encoded_df = pd.DataFrame(encoded_features, columns=encoded_feature_names, index=data.index)

    # Drop the original categorical columns from the main DataFrame
    data = data.drop(columns=current_categorical_cols, errors='ignore')

    # Concatenate the original DataFrame (now without the original categorical columns) with the new one-hot encoded DataFrame
    data = pd.concat([data, encoded_df], axis=1)

data.head()
# Out:
#    Applicant_Income  Coapplicant_Income   Age  Dependents  Credit_Score  \
# 0           17795.0              1387.0  51.0         0.0         637.0
# 1            2860.0              2679.0  46.0         3.0         621.0
# 2            7390.0              2106.0  25.0         2.0         674.0
# 3           13964.0              8173.0  40.0         2.0         579.0
# 4           13284.0              4223.0  31.0         2.0         721.0
#
#    Existing_Loans  DTI_Ratio  Savings  Collateral_Value  Loan_Amount  ...  \
# 0             4.0       0.53  19403.0           45638.0      16619.0  ...
# 1             2.0       0.30   2580.0           49272.0      38687.0  ...
# 2             4.0       0.20  13844.0            6908.0      27943.0  ...
# 3             3.0       0.31   9553.0           10844.0      27819.0  ...
# 4             1.0       0.29   9386.0           37629.0      12741.0  ...
#
#    Employer_Category_Government  Employer_Category_MNC  \
# ...

# %%
num_cols =data.select_dtypes(include=['int64', 'float64']).columns
corr_matrix = data[num_cols].corr()

sns.heatmap(corr_matrix, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix["Loan_Approved"].sort_values(ascending=False)
# Out:
# Loan_Approved                      1.000000
# Credit_Score                       0.451175
# Applicant_Income                   0.119796
# Employer_Category_MNC              0.069049
# Loan_Purpose_Personal              0.034043
# Marital_Status_Single              0.030182
# Property_Area_Urban                0.025963
# Collateral_Value                   0.021868
# Coapplicant_Income                 0.004230
# Loan_Purpose_Home                  0.002118
# Employment_Status_Self-employed   -0.001337
# Employer_Category_Private         -0.003347
# Property_Area_Semiurban           -0.012967
# Savings                           -0.013437
# Loan_Purpose_Education            -0.016684
# Employer_Category_Unemployed      -0.021468
# Age                               -0.022343
# Dependents                        -0.023811
# Existing_Loans                    -0.034794
# Employer_Category_Government      -0.039187
# Employment_Status_Salaried        -0.041428
# ...

# %% [markdown]
# # Splitting the Dataset

# %%
x = data.drop(columns=['Loan_Approved'])
y = data['Loan_Approved']

# %%
x.head()
# Out:
#    Applicant_Income  Coapplicant_Income   Age  Dependents  Credit_Score  \
# 0           17795.0              1387.0  51.0         0.0         637.0
# 1            2860.0              2679.0  46.0         3.0         621.0
# 2            7390.0              2106.0  25.0         2.0         674.0
# 3           13964.0              8173.0  40.0         2.0         579.0
# 4           13284.0              4223.0  31.0         2.0         721.0
#
#    Existing_Loans  DTI_Ratio  Savings  Collateral_Value  Loan_Amount  ...  \
# 0             4.0       0.53  19403.0           45638.0      16619.0  ...
# 1             2.0       0.30   2580.0           49272.0      38687.0  ...
# 2             4.0       0.20  13844.0            6908.0      27943.0  ...
# 3             3.0       0.31   9553.0           10844.0      27819.0  ...
# 4             1.0       0.29   9386.0           37629.0      12741.0  ...
#
#    Employer_Category_Government  Employer_Category_MNC  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Loan_Approved, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
X_test_scaled
# Out:
# array([[ 0.42610546,  0.55091079,  1.19037073, ..., -0.46454867,
#          2.081666  , -1.05395348],
#        [ 1.00971366,  0.58995935,  0.18392964, ..., -0.46454867,
#         -0.48038446, -1.05395348],
#        [-0.67557096, -0.54558674,  1.09887608, ..., -0.46454867,
#         -0.48038446, -1.05395348],
#        ...,
#        [-0.67980585, -0.10106072,  1.28186537, ..., -0.46454867,
#         -0.48038446, -1.05395348],
#        [-0.37650705, -0.97825874, -0.54802752, ..., -0.46454867,
#         -0.48038446, -1.05395348],
#        [-0.73647272, -1.24497436,  0.73289751, ..., -0.46454867,
#         -0.48038446, -1.05395348]])

# %% [markdown]
# # Train and Evaluate the model

# %% [markdown]
# 1  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score,recall_score, confusion_matrix

log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)

y_pred = log_reg.predict(X_test_scaled)

confusion_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_matrix)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

precision = precision_score(y_test, y_pred)
print(f"Precision: {precision}")

recall = recall_score(y_test, y_pred)
print(f"Recall: {recall}")
# Out:
# Confusion Matrix:
# [[126  13]
#  [ 14  47]]
# Accuracy: 0.865
# Precision: 0.7833333333333333
# Recall: 0.7704918032786885

# %% [markdown]
# 2 KNN Classifier Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score,recall_score, confusion_matrix

knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train_scaled, y_train)

y_pred = knn_classifier.predict(X_test_scaled)

confusion_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_matrix)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

precision = precision_score(y_test, y_pred)
print(f"Precision: {precision}")

recall = recall_score(y_test, y_pred)
print(f"Recall: {recall}")
# Out:
# Confusion Matrix:
# [[120  19]
#  [ 29  32]]
# Accuracy: 0.76
# Precision: 0.6274509803921569
# Recall: 0.5245901639344263

# %% [markdown]
# 3 Naive Bayes Alorithm

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score,recall_score, confusion_matrix

nb_classifier = GaussianNB()
nb_classifier.fit(X_train_scaled, y_train)

y_pred = nb_classifier.predict(X_test_scaled)

confusion_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_matrix)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

precision = precision_score(y_test, y_pred)
print(f"Precision: {precision}")

recall = recall_score(y_test, y_pred)
print(f"Recall: {recall}")
# Out:
# Confusion Matrix:
# [[128  11]
#  [ 16  45]]
# Accuracy: 0.865
# Precision: 0.8035714285714286
# Recall: 0.7377049180327869

# %% [markdown]
# # The Best Model Based on the Precision Score => Naive Bayes Algorithm
